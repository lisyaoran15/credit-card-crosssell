# %%
import pandas as pd

# %%
df = pd.read_csv("D:/credit-card-crosssell/data/data_model.csv")

# %%
df
# Out:
#       customer_id observation_date  age gender province  tenure_months  \
# 0        KH000000       2024-11-29   39      M       CT             19
# 1        KH000001       2024-03-01   34      M      HCM              6
# 2        KH000002       2023-09-08   40      F      HCM            120
# 3        KH000003       2024-05-09   47      F       HN             16
# 4        KH000004       2023-03-05   33      M    OTHER             10
# ...           ...              ...  ...    ...      ...            ...
# 49995    KH049995       2023-09-17   35      F      HCM             38
# 49996    KH049996       2024-08-29   35      M      HCM             18
# 49997    KH049997       2023-03-26   39      F       HN             20
# 49998    KH049998       2023-11-29   37      F       HN             33
# 49999    KH049999       2023-07-19   47      M      HCM             29
#
#        monthly_salary  salary_regularity  salary_growth_3m  avg_monthly_spend  \
# ...
