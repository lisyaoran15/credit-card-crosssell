# %%
import pandas as pd

# %%
df = pd.read_csv("D:/credit-card-crosssell/data/data_model.csv")

# %% [markdown]
# # ETL some features

# %% [markdown]
# with given data, try to caputre:
# -

# %%
df['observation_date'] = pd.to_datetime(df['observation_date'])

# %%
train_test = df[df['observation_date'].dt.year != 2024]  # 2022-2023 → train và test
oot        = df[df['observation_date'].dt.year == 2024]  # 2024 → out-of-time validation

# %%
train_test['monthly_salary'].describe()
# Out:
# count      33315.0
# mean     5000000.0
# std            0.0
# min      5000000.0
# 25%      5000000.0
# 50%      5000000.0
# 75%      5000000.0
# max      5000000.0
# Name: monthly_salary, dtype: float64

# %% [markdown]
# train_test
